# %%
import pandas as pd
from pymongo import MongoClient

# %%
client = MongoClient("mongodb://localhost/datamad0320")
db = client.get_database()

# %%
cur = db.companiesSF.find({"office":{
    "$geoWithin": {"$geometry": {
             "type" : "Polygon" ,"coordinates":[ [ [ -122.42168 , 37.7683 ], [ -122.42216 , 37.7646 ], [ -122.40962, -37.7669 ] , [ -122.41379 , 37.7714 ] , [ -122.42168 , 37.7683 ]]]}}}})

# %%
df = pd.DataFrame(cur)
display(df.head(),df.shape)
# Out:
#                         _id          name    category_code  \
# 0  5e9d3c7155122cdd5bd9ccaf    Pageflakes              web
# 1  5e9d3c7155122cdd5bd9cce5          Kiva          finance
# 2  5e9d3c7155122cdd5bd9cd09    Automattic              web
# 3  5e9d3c7155122cdd5bd9cd1f  Doppelganger              web
# 4  5e9d3c7155122cdd5bd9cd35         Mogad  network_hosting
#
#    number_of_employees  founded_year           city  \
# 0                 20.0        2006.0  San Francisco
# 1                  NaN        2005.0  San Francisco
# 2                200.0        2005.0  San Francisco
# 3                  NaN           NaN  San Francisco
# 4                  2.0        2007.0  San Francisco
#
#                                               office    state  \
# 0  {'type': 'Point', 'coordinates': [-122.414689,...  success
# 1  {'type': 'Point', 'coordinates': [-122.4147, 3...  success
# 2  {'type': 'Point', 'coordinates': [-122.421344,...  success
# ...

# %%
df = df.drop(columns="_id")
df.head()
# Out:
#            name    category_code  number_of_employees  founded_year  \
# 0    Pageflakes              web                 20.0        2006.0
# 1          Kiva          finance                  NaN        2005.0
# 2    Automattic              web                200.0        2005.0
# 3  Doppelganger              web                  NaN           NaN
# 4         Mogad  network_hosting                  2.0        2007.0
#
#             city                                             office    state  \
# 0  San Francisco  {'type': 'Point', 'coordinates': [-122.414689,...  success
# 1  San Francisco  {'type': 'Point', 'coordinates': [-122.4147, 3...  success
# 2  San Francisco  {'type': 'Point', 'coordinates': [-122.421344,...  success
# 3  San Francisco  {'type': 'Point', 'coordinates': [-122.413912,...  success
# 4  San Francisco  {'type': 'Point', 'coordinates': [-122.421778,...  success
#
#    total_money_raised ($k) money_state
# 0                   4100.0     success
# ...

# %%
df.to_json("../output/companies_near.json",orient="records")

# %%
df_startup = df[df["founded_year"]<2003]
df_startup
# Out:
#                          _id                      name category_code  \
# 4   5e9c54de68509542ddf7d853                 RateItAll           web
# 10  5e9c54de68509542ddf7d97c                       OQO        mobile
# 13  5e9c54de68509542ddf7da49  PB Strategic Consultancy        mobile
#
#     number_of_employees  founded_year           city  \
# 4                   6.0        1999.0  San Francisco
# 10                  NaN        2000.0  San Francisco
# 13                  5.0        1999.0  San Francisco
#
#                                                office    state  \
# 4   {'type': 'Point', 'coordinates': [-122.418137,...  success
# 10  {'type': 'Point', 'coordinates': [-122.415869,...  success
# 13  {'type': 'Point', 'coordinates': [-122.4184108...  success
#
#     total_money_raised ($k) money_state
# 4                    1400.0     success
# 10                  39800.0     success
# 13                      0.0    success2

# %%
list(df_startup["office"])
# Out:
# [{'type': 'Point', 'coordinates': [-122.418137, 37.755012]},
#  {'type': 'Point', 'coordinates': [-122.415869, 37.759117]},
#  {'type': 'Point', 'coordinates': [-122.4184108, 37.7581148]}]

# %%
#lejos de las 3 empresas más antiguas
cur = db.companies_near.find({"office": {
         "$near": {
           "$geometry": {"type" : "Point" ,"coordinates":[-122.418137, 37.755012]},
           "$minDistance": 1000}}})

# %%
df_FAR = pd.DataFrame(cur)
display(df_FAR.head(),df_FAR.shape)
# Out:
#                         _id         name    category_code  \
# 0  5e9d3d3b55122cdd5bd9d0e6        Mogad  network_hosting
# 1  5e9d3d3b55122cdd5bd9d0ee  CrowdFlower       enterprise
# 2  5e9d3d3b55122cdd5bd9d0e1   Automattic              web
# 3  5e9d3d3b55122cdd5bd9d0f2       Jobnob           search
# 4  5e9d3d3b55122cdd5bd9d0e4        Cucku       enterprise
#
#    number_of_employees  founded_year           city  \
# 0                  2.0        2007.0  San Francisco
# 1                 49.0        2007.0  San Francisco
# 2                200.0        2005.0  San Francisco
# 3                  NaN        2008.0  San Francisco
# 4                  NaN        2007.0  San Francisco
#
#                                               office    state  \
# 0  {'type': 'Point', 'coordinates': [-122.421778,...  success
# 1  {'type': 'Point', 'coordinates': [-122.4204782...  success
# 2  {'type': 'Point', 'coordinates': [-122.421344,...  success
# ...

# %%
#lejos de las 3 empresas más antiguas
cur = db.companies_near.find({"office": {
         "$near": {
           "$geometry": {"type" : "Point" ,"coordinates":[-122.415869, 37.759117]},
           "$minDistance": 1000}}})

# %%
df_FAR = pd.DataFrame(cur)
display(df_FAR.head(),df_FAR.shape)
# Out:
#                         _id        name category_code  number_of_employees  \
# 0  5e9d3d3b55122cdd5bd9d0df    Aardvark           web                 30.0
# 1  5e9d3d3b55122cdd5bd9d0e1  Automattic           web                200.0
# 2  5e9d3d3b55122cdd5bd9d0e4       Cucku    enterprise                  NaN
# 3  5e9d3d3b55122cdd5bd9d0f2      Jobnob        search                  NaN
#
#    founded_year           city  \
# 0        2007.0  San Francisco
# 1        2005.0  San Francisco
# 2        2007.0  San Francisco
# 3        2008.0  San Francisco
#
#                                               office    state  \
# 0  {'type': 'Point', 'coordinates': [-122.415813,...  success
# 1  {'type': 'Point', 'coordinates': [-122.421344,...  success
# 2  {'type': 'Point', 'coordinates': [-122.41748, ...  success
# 3  {'type': 'Point', 'coordinates': [-122.4219405...  success
#
#    total_money_raised ($k) money_state
# 0                   6000.0     success
# ...

# %%
#lejos de las 3 empresas más antiguas
cur = db.companies_near.find({"office": {
         "$near": {
           "$geometry": {"type" : "Point" ,"coordinates":[-122.4184108, 37.7581148]},
           "$minDistance": 1000}}})

# %%
df_FAR = pd.DataFrame(cur)
display(df_FAR.head(),df_FAR.shape)
# Out:
#                         _id        name category_code  number_of_employees  \
# 0  5e9d3d3b55122cdd5bd9d0df    Aardvark           web                 30.0
# 1  5e9d3d3b55122cdd5bd9d0e1  Automattic           web                200.0
# 2  5e9d3d3b55122cdd5bd9d0f2      Jobnob        search                  NaN
# 3  5e9d3d3b55122cdd5bd9d0e4       Cucku    enterprise                  NaN
#
#    founded_year           city  \
# 0        2007.0  San Francisco
# 1        2005.0  San Francisco
# 2        2008.0  San Francisco
# 3        2007.0  San Francisco
#
#                                               office    state  \
# 0  {'type': 'Point', 'coordinates': [-122.415813,...  success
# 1  {'type': 'Point', 'coordinates': [-122.421344,...  success
# 2  {'type': 'Point', 'coordinates': [-122.4219405...  success
# 3  {'type': 'Point', 'coordinates': [-122.41748, ...  success
#
#    total_money_raised ($k) money_state
# 0                   6000.0     success
# ...
